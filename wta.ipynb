# %% [markdown]
# <a href="https://colab.research.google.com/github/sjahnavia/wta-tennis/blob/main/wta.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data=pd.read_csv('/content/wta_matches_2000.csv')

# %%
data.head()
# Out:
#                tourney_id     tourney_name surface  draw_size tourney_level  \
# 0  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 1  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 2  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 3  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
# 4  2000-W-SL-AUS-01A-2000  Australian Open    Hard        128             G
#
#    tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 0      20000117          1     200001          1.0          NaN  ...
# 1      20000117          2     200003          NaN          NaN  ...
# 2      20000117          3     200006          NaN          NaN  ...
# 3      20000117          4     200008          NaN          NaN  ...
# 4      20000117          5     200009          NaN          NaN  ...
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# ...

# %%
data.tail()
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 2888  2000-D214  Fed Cup G2 RRB: SRI vs SYR    Hard          4             D
# 2889  2000-D215  Fed Cup G1 RRB: SIN vs TPE    Hard          4             D
# 2890  2000-D215  Fed Cup G1 RRB: SIN vs TPE    Hard          4             D
# 2891  2000-D216  Fed Cup G2 RRA: POC vs UZB    Hard          4             D
# 2892  2000-D216  Fed Cup G2 RRA: POC vs UZB    Hard          4             D
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 2888      20000426          2     208378          NaN          NaN  ...
# 2889      20000425          1     207247          NaN          NaN  ...
# 2890      20000425          2     200091          NaN          NaN  ...
# 2891      20000425          1     204169          NaN          NaN  ...
# 2892      20000425          2     201204          NaN          NaN  ...
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# ...

# %%
data.tail(5)
# Out:
#      tourney_id                tourney_name surface  draw_size tourney_level  \
# 2888  2000-D214  Fed Cup G2 RRB: SRI vs SYR    Hard          4             D
# 2889  2000-D215  Fed Cup G1 RRB: SIN vs TPE    Hard          4             D
# 2890  2000-D215  Fed Cup G1 RRB: SIN vs TPE    Hard          4             D
# 2891  2000-D216  Fed Cup G2 RRA: POC vs UZB    Hard          4             D
# 2892  2000-D216  Fed Cup G2 RRA: POC vs UZB    Hard          4             D
#
#       tourney_date  match_num  winner_id  winner_seed winner_entry  ...  \
# 2888      20000426          2     208378          NaN          NaN  ...
# 2889      20000425          1     207247          NaN          NaN  ...
# 2890      20000425          2     200091          NaN          NaN  ...
# 2891      20000425          1     204169          NaN          NaN  ...
# 2892      20000425          2     201204          NaN          NaN  ...
#
#               loser_name loser_hand  loser_ht loser_ioc  loser_age  \
# ...

# %%
data.isnull().sum()
# Out:
# tourney_id               0
# tourney_name             0
# surface                  0
# draw_size                0
# tourney_level            0
# tourney_date             0
# match_num                0
# winner_id                0
# winner_seed           1759
# winner_entry          2576
# winner_name              0
# winner_hand             74
# winner_ht             1866
# winner_ioc               0
# winner_age               0
# winner_rank            184
# winner_rank_points     184
# loser_id                 0
# loser_seed            2338
# loser_entry           2339
# loser_name               0
# loser_hand             169
# loser_ht              2250
# loser_ioc                0
# loser_age                0
# loser_rank             291
# loser_rank_points      291
# score                    0
# best_of                  0
# round                    0
# dtype: int64

# %%
data.shape
# Out:
# (2893, 30)

# %%
data.describe()
# Out:
#          draw_size  tourney_date    match_num      winner_id  winner_seed  \
# count  2893.000000  2.893000e+03  2893.000000    2893.000000  1134.000000
# mean     50.475631  2.000055e+07    25.164535  200883.731766     5.659612
# std      41.046778  2.810468e+02    27.730224    2275.260223     4.439911
# min       4.000000  2.000010e+07     1.000000  200001.000000     1.000000
# 25%      28.000000  2.000032e+07     5.000000  200048.000000     2.000000
# 50%      32.000000  2.000052e+07    17.000000  200090.000000     5.000000
# 75%      64.000000  2.000073e+07    30.000000  200653.000000     8.000000
# max     128.000000  2.000112e+07   127.000000  212746.000000    32.000000
#
#          winner_ht   winner_age  winner_rank  winner_rank_points  \
# count  1027.000000  2893.000000  2709.000000         2709.000000
# mean    172.361246    23.142726    86.466593         1134.478774
# std       7.250931     3.683128   135.094086         1295.358702
# ...
